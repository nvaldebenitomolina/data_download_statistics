# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import pandas as pd 
import numpy as np
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style 
import matplotlib.ticker as ticker
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import seaborn as sns

# %%
style.use('seaborn-paper') #sets the size of the charts
sns.axes_style({'font.sans-serif': [
  'Liberation Sans']})

sns.set(font_scale=0.9)

# %%
#df = pd.read_csv("wordpress_date.csv", sep=',', encoding='utf-8') 
#date   		= df['date plot']
#dateparsed 	= df['dateparsed']
#category  	= df['category']

# %%
# Import file into pandas dataframe, identifying the date column to be converted to datetime
# create xticks

#xticks = df['date plot']
#time_real=[]
#for n in range(0,len(xticks)):
#    time_real.append(xticks[n].split('-')[0])
#df['year'] = time_real
#df.to_csv("wordpress_date_new.csv", sep=',', encoding='utf-8')
df = pd.read_csv("../output/wordpress_english.csv", sep=',', encoding='utf-8') 
date   		= df['date plot']
dateparsed 	= df['dateparsed']
category  	= df['category']
df=df.dropna(subset=['category','year'])
df['year'] = df['year'].astype(int)

ax = sns.countplot(y=df['year'])
for p in ax.patches:
    percentage = p.get_width()
    x = p.get_x() + p.get_width()+0.02
    y = p.get_y() + p.get_height()/2
    ax.annotate(percentage, (x, y))
plt.tight_layout()
#print(time_real)
plt.savefig('../images/figure.png', dpi=1000, bbox_inches='tight')
plt.show()

plt.show()

# %% [markdown]
# # AREA Y SERIE DE TIEMPO

# %%
sns.set(style="whitegrid")
#sns.set(rc={'figure.figsize':(11.7,50)})
#ax = sns.countplot(y="area", hue="year", data=df)
#plt.savefig('images/figure0.png', dpi=1000, bbox_inches='tight')
#plt.show()
#plt.close()

# %% [markdown]
# # CATEGORIA

# %%
sns.set(rc={'figure.figsize':(11.7,10)})
area=df['area']
plt.pie(np.array(df['category'].value_counts()))
plt.legend(labels=df['category'].value_counts().index, loc='lower right', bbox_to_anchor=(1.3,0.5))
#plt.legend(labels=names,loc='lower right', bbox_to_anchor=(2,0.5))
plt.savefig('../images/figure0.png', dpi=1000, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# # AREA

# %%
pkmn_type_colors = ['#5975A4',  # Grass
	'#CC8862',  # Fire
	'#5F9E6E',  # Water
	'#B55D5F',  # Bug
	'#857AAB',  # Normal
	'#8C7766',  # Poison                        
	'#D39AC2',  # Electric
	'#E0C068',  # Ground
	'#EE99AC',  # Fairy
	'#C03028',  # Fighting
	'#F85888',  # Psychic
	'#B8A038',  # Rock
	'#705898',  # Ghost
	'#98D8D8',  # Ice
	'#7038F8',  # Dragon
	]
area=df['area']
ax = sns.countplot(y='area', data=df, palette=pkmn_type_colors,order=df['area'].value_counts().index)
#plt.title('Distribución de '+categoryname)
#plt.ylabel('Número de categorias')
#ax.set_xlabel('Cantidad de Investigadores')
sns.set(rc={'figure.figsize':(14,10)})

for p in ax.patches:
	percentage = p.get_width()
	x = p.get_x() + p.get_width() + 0.02
	y = p.get_y() + p.get_height()/2
	ax.annotate(percentage, (x, y))
plt.tight_layout()
#plt.legend(labels=names,loc='lower right', bbox_to_anchor=(2,0.5))
plt.savefig('../images/figure1.png', dpi=1000, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# # TIPO DE INSTITUCIÓN

# %%
sns.set(rc={'figure.figsize':(11.7,10)})
df=df.dropna(subset=['category','Type of institution'])
names=np.asarray(df['Type of institution'].value_counts().index)
size=df['Type of institution'].value_counts()
print(names)
print(np.array(size))
print(np.asarray(df['Type of institution'].value_counts().index))
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')

plt.pie(np.array(df['Type of institution'].value_counts()))
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.legend(labels=names, loc='lower right', bbox_to_anchor=(1.7,0.5))
#plt.legend(labels=names,loc='lower right', bbox_to_anchor=(2,0.5))
#plt.savefig('images/figure2.png', dpi=1000, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# ['Universities' 'Private sector (companies)'
#  'Public sector (state agencies)' 'Center Research'
#  'Other educational institutions'
#  'Trade-union associations and other organizations' 'NGO']
# [888 327 112  47  20  15   4]
# ['Universities' 'Private sector (companies)'
#  'Public sector (state agencies)' 'Center Research'
#  'Other educational institutions'
#  'Trade-union associations and other organizations' 'NGO']

# %%
ax = sns.countplot(y="Type of institution", hue="year", data=df)
#plt.savefig('images/figure0.png', dpi=1000, bbox_inches='tight')
plt.show()
plt.close()

# %%
#import sys
#!{sys.executable} -m pip install squarify
sns.set(rc={'figure.figsize':(24,15)})
import matplotlib
import squarify # pip install squarify (algorithm for treemap)
df=df.dropna(subset=['category','Type of institution'])
names=np.asarray(df['Type of institution'].value_counts().index)
size=df['Type of institution'].value_counts() 
print(names)
names = ['Universities', 'Private sector (companies)',
 'Public sector\n (state agencies)' ,'Research Center',
 'Other\n educational\n institutions',
 'Trade-union\n associations\n and other\n organizations', 'NGO']
colors=["#E64B18","#377EB8","#5CAF4A","#995AA3","#F37D0E","#F9E737","#A65628"]
# Change color
squarify.plot(df['Type of institution'].value_counts(), label=names, color=colors, alpha=.8, text_kwargs={'fontsize':17})
plt.axis('off')

#plt.legend(labels=names,loc='lower right', bbox_to_anchor=(2,0.5))
#plt.savefig('images/figure4.png', dpi=1000, bbox_inches='tight')
plt.savefig('../images/figure2.png', dpi=1000, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# ['Universities' 'Private sector (companies)'
#  'Public sector (state agencies)' 'Center Research'
#  'Other educational institutions'
#  'Trade-union associations and other organizations' 'NGO']

# %% [markdown]
# # TIPO DE USO

# %%
df=df.dropna(subset=['category','Type of use'])
sns.set(rc={'figure.figsize':(5,5)})
names=np.asarray(df['Type of use'].value_counts().index)
size=df['Type of use'].value_counts()
print(names)
print(size)
print(np.array(size))
print(np.asarray(df['Type of use'].value_counts().index))
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')

plt.pie(np.array(df['Type of use'].value_counts()),labels=names)
p=plt.gcf()
p.gca().add_artist(my_circle)
#plt.legend(labels=names,loc='lower right', bbox_to_anchor=(2,0.5))
plt.savefig('../images/figure3.png', dpi=1000, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# ['Data Analysis' 'Research' 'Teaching' 'Engineering projects']
# Data Analysis           715
# Research                508
# Teaching                111
# Engineering projects    105
# Name: Type of use, dtype: int64
# [715 508 111 105]
# ['Data Analysis' 'Research' 'Teaching' 'Engineering projects']

# %%
ax = sns.countplot(y="Tipo de uso", hue="year", data=df)
#plt.savefig('images/figure0.png', dpi=1000, bbox_inches='tight')
sns.set(rc={'figure.figsize':(10,10)})
plt.show()
plt.close()

# %% [markdown]
# # PAISES

# %%
# import the library
import folium
import pandas as pd
 
# Make a data frame with dots to show on the map
data = pd.DataFrame({
   'lat':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
   'lon':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
   'name':['Buenos Aires', 'Paris', 'melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador'],
   'value':[10,12,40,70,23,43,100,43]
})
data
 
# Make an empty map
m = folium.Map(location=[20,0], zoom_start=2)
 
# I can add marker one by one on the map
for i in range(0,len(data)):
   folium.Circle(
      location=[data.iloc[i]['lon'], data.iloc[i]['lat']],
      popup=data.iloc[i]['name'],
      radius=float(data.iloc[i]['value']*10000),
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(m)

# Save it as html
m.save('../images/mymap.html')

# %%
country = df['country']
print(country.unique())
# Out:
# ['Argentina' 'Chile' 'Francia' 'Reino Unido' nan 'Alemania' 'Australia'
#  'Ecuador' 'Estados Unidos' 'Portugal' 'Uruguay' 'Canadá' 'Colombia'
#  'Mexico' 'Perú' 'Arabia Saudita' 'España' 'Paises Bajos' 'Brasil'
#  'Italia' 'Nueva Zelanda' 'Austria' 'Belgica' 'Bolivia' 'Guatemala'
#  'Honduras' 'Inglaterra' 'Letonia' 'Marruecos' 'Nicaragua']

# %%
def country_to_english(country):
    if country =='Alemania':
        return 'Germany'
    elif country == 'Arabia Saudita':
        return 'Saudi Arabia'
    elif country == 'Argentina':
        return 'Argentina'
    elif country == 'Australia':
        return 'Australia'
    elif country == 'Austria':
        return 'Austria'
    elif country == 'Belgica':
        return 'Belgium'
    elif country == 'Bolivia':
        return 'Bolivia'
    elif country == 'Brasil':
        return 'Brazil'
    elif country == 'Canadá':
        return 'Canada'
    elif country == 'Chile':
        return 'Chile'
    elif country == 'Colombia':
        return 'Colombia'
    elif country == 'Ecuador':
        return 'Ecuador'
    elif country == 'España':
        return 'Spain'
    elif country == 'Estados Unidos':
        return 'United States'
    elif country == 'Francia':
        return 'France'
    elif country == 'Guatemala':
        return 'Guatemala'     
    elif country == 'Honduras':
        return 'Honduras'
    elif country == 'Inglaterra': 
        return 'United Kingdom'
    elif country == 'Italia':
        return 'Italy'
    elif country == 'Letonia': 
        return 'Latvia'
    elif country == 'Marruecos':
        return 'Morroco'
    elif country == 'Mexico':
        return 'Mexico'
    elif country == 'Nicaragua':
        return 'Nicaragua'
    elif country == 'Nueva Zelanda':
        return 'New Zealand'
    elif country == 'Paises Bajos':
        return 'Netherlands'
    elif country == 'Perú':
        return 'Peru'
    elif country == 'Portugal':
        return 'Portugal'
    elif country == 'Reino Unido':
        return 'United Kingdom'
    elif country == 'Uruguay':
        return 'Uruguay'

# %%
#{sys.executable} -m pip install https://github.com/matplotlib/basemap/archive/v1.1.0.tar.gz
import geopandas as gpd

country_df = gpd.read_file("../input/TM_WORLD_BORDERS-0.3.shp")
def get_country_window_lat(country):
    return country_df[country_df["NAME"].str.lower() == country.lower()].geometry.values[0].centroid.x

def get_country_window_lon(country):
    return country_df[country_df["NAME"].str.lower() == country.lower()].geometry.values[0].centroid.y

countries = df['country'].value_counts().index

country=[]
lon=[]
lat=[]
ene=[]
print(df['country'].value_counts().index)
for n in range(0,len(countries)):
    if countries[n] != 'Marruecos':
        print(countries[n])
        x=get_country_window_lat(country_to_english(countries[n]))
        y=get_country_window_lon(country_to_english(countries[n]))
        country.append(country_to_english(countries[n]))
        lon.append(x)
        lat.append(y)
        if countries[n] != 'Chile':
            ene.append(df['country'].value_counts()[n])
        else:
            ene.append(100)
        print(country_to_english(countries[n]))
        print(df['country'].value_counts().index[n])
              
            
        
    else:
        lon.append(-7.0926199)
        lat.append(31.7917023)
        country.append(country_to_english(countries[n]))
        print(country_to_english(countries[n]))
        print(df['country'].value_counts().index[n])
        ene.append(df['country'].value_counts()[n])

#df.set_index(["Person", "Single"]).count(level="Person")
print(df['country'].value_counts())
print(df['country'].value_counts().index[2])
print(df['country'].value_counts().index)

df_countries = pd.DataFrame(columns=['lon','lat','name','value'])
df_countries['lat'] = lon
df_countries['lon'] = lat
df_countries['name'] = country
df_countries['value'] = ene
print(df_countries)
# Out:
# Index(['Chile', 'Estados Unidos', 'Alemania', 'Reino Unido', 'Australia',
#        'Perú', 'Mexico', 'Argentina', 'Colombia', 'Francia', 'España',
#        'Ecuador', 'Bolivia', 'Canadá', 'Italia', 'Uruguay', 'Brasil',
#        'Paises Bajos', 'Guatemala', 'Belgica', 'Nueva Zelanda', 'Inglaterra',
#        'Portugal', 'Honduras', 'Nicaragua', 'Arabia Saudita', 'Austria',
#        'Marruecos', 'Letonia'],
#       dtype='object')
# Chile
# Chile
# Chile
# Estados Unidos
# United States
# Estados Unidos
# Alemania
# Germany
# Alemania
# Reino Unido
# United Kingdom
# Reino Unido
# Australia
# Australia
# Australia
# Perú
# Peru
# Perú
# Mexico
# Mexico
# Mexico
# Argentina
# Argentina
# Argentina
# Colombia
# Colombia
# Colombia
# Francia
# France
# Francia
# España
# Spain
# España
# Ecuador
# Ecuador
# Ecuador
# Bolivia
# Bolivia
# Bolivia
# Canadá
# Canada
# Canadá
# Italia
# Italy
# Italia
# Uruguay
# Uruguay
# Uruguay
# Brasil
# Brazil
# Brasil
# Paises Bajos
# Netherlands
# Paises Bajos
# Guatemala
# Guatemala
# Guatemala
# Belgica
# Belgium
# Belgica
# Nueva Zelanda
# New Zealand
# Nueva Zelanda
# Inglaterra
# United Kingdom
# Inglaterra
# Portugal
# Portugal
# Portugal
# Honduras
# Honduras
# Honduras
# Nicaragua
# Nicaragua
# Nicaragua
# Arabia Saudita
# Saudi Arabia
# Arabia Saudita
# Austria
# Austria
# Austria
# Morroco
# Marruecos
# Letonia
# Latvia
# Letonia
# Chile             1238
# Estados Unidos      26
# Alemania            20
# Reino Unido         16
# Australia           14
# Perú                12
# Mexico              10
# Argentina           10
# Colombia             9
# Francia              7
# España               6
# Ecuador              4
# Bolivia              3
# Canadá               3
# Italia               3
# Uruguay              2
# Brasil               2
# Paises Bajos         1
# Guatemala            1
# Belgica              1
# Nueva Zelanda        1
# Inglaterra           1
# Portugal             1
# Honduras             1
# Nicaragua            1
# Arabia Saudita       1
# Austria              1
# Marruecos            1
# Letonia              1
# Name: country, dtype: int64
# Alemania
# Index(['Chile', 'Estados Unidos', 'Alemania', 'Reino Unido', 'Australia',
#        'Perú', 'Mexico', 'Argentina', 'Colombia', 'Francia', 'España',
#        'Ecuador', 'Bolivia', 'Canadá', 'Italia', 'Uruguay', 'Brasil',
#        'Paises Bajos', 'Guatemala', 'Belgica', 'Nueva Zelanda', 'Inglaterra',
#        'Portugal', 'Honduras', 'Nicaragua', 'Arabia Saudita', 'Austria',
#        'Marruecos', 'Letonia'],
#       dtype='object')
#           lon         lat            name  value
# 0  -37.868137  -71.380098           Chile    100
# 1   45.695478 -112.493550   United States     26
# 2   51.110154   10.392330         Germany     20
# 3   54.160179   -2.900499  United Kingdom     16
# 4  -25.733260  134.490976       Australia     14
# 5   -9.163771  -74.375407            Peru     12
# 6   23.950932 -102.534994          Mexico     10
# 7  -35.376672  -65.167485       Argentina     10
# 8    3.900374  -73.075764        Colombia      9
# 9   46.564875    2.550424          France      7
# 10  40.227496   -3.649311           Spain      6
# 11  -1.425283  -78.780962         Ecuador      4
# 12 -16.715110  -64.670549         Bolivia      3
# 13  61.393066  -98.260946          Canada      3
# 14  42.791162   12.071670           Italy      3
# 15 -32.799570  -56.012174         Uruguay      2
# 16 -10.772282  -53.088754          Brazil      2
# 17  52.253576    5.600998     Netherlands      1
# 18  15.702303  -90.356949       Guatemala      1
# 19  50.642952    4.664348         Belgium      1
# 20 -41.837112  171.603996     New Zealand      1
# 21  54.160179   -2.900499  United Kingdom      1
# 22  39.602695   -8.467361        Portugal      1
# 23  14.819348  -86.619659        Honduras      1
# 24  12.840070  -85.033750       Nicaragua      1
# 25  24.023380   44.585104    Saudi Arabia      1
# 26  47.592958   14.139988         Austria      1
# 27  31.791702   -7.092620         Morroco      1
# 28  56.857669   24.929153          Latvia      1

# %%
# import the library
import folium
import pandas as pd
 
# Make a data frame with dots to show on the map
data = pd.DataFrame({
   'lat':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
   'lon':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
   'name':['Buenos Aires', 'Paris', 'melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador'],
   'value':[10,12,40,70,23,43,100,43]
})
data
data=df_countries
# Make an empty map
m = folium.Map(location=[20,0], zoom_start=2)
 
# I can add marker one by one on the map
for i in range(0,len(data)):
   folium.Circle(
      location=[data.iloc[i]['lon'], data.iloc[i]['lat']],
      popup=data.iloc[i]['name'],
      radius=float(data.iloc[i]['value']*30000),
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(m)

# Save it as html
m.save('../images/mymap.html')

# %% [markdown]
# # Razones de uso

# %%
# Libraries
#import sys
#!{sys.executable} -m pip install wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image    # to import the image
 
# Create a list of word (https://en.wikipedia.org/wiki/Data_visualization)
#text=("Data visualization or data visualisation is viewed by many disciplines as a modern equivalent of visual communication. It involves the creation and study of the visual representation of data, meaning information that has been abstracted in some schematic form, including attributes or variables for the units of information A primary goal of data visualization is to communicate information clearly and efficiently via statistical graphics, plots and information graphics. Numerical data may be encoded using dots, lines, or bars, to visually communicate a quantitative message.[2] Effective visualization helps users analyze and reason about data and evidence. It makes complex data more accessible, understandable and usable. Users may have particular analytical tasks, such as making comparisons or understanding causality, and the design principle of the graphic (i.e., showing comparisons or showing causality) follows the task. Tables are generally used where users will look up a specific measurement, while charts of various types are used to show patterns or relationships in the data for one or more variables")
reason=df['reason']
text=''
for n in reason:
    if type(n) == str:
        #print(type(n))
        text+=n
text=text.replace(' de ','').replace(' br ','').replace(' en ','').replace(' para ','')
print(text)
# Load the image (http://python-graph-gallery.com/wp-content/uploads/wave.jpg)
wave_mask = np.array(Image.open( "inp/wave.jpeg"))
 
# Make the figure
wordcloud = WordCloud(mask=wave_mask).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
# Out:
# Evaluacion estadistica y analisiscaudalesla Cuenca del maipo.Evaluar evolución precipitacionesComo asesorla gobernaciónPetorcalas mesas del agua requiero informar a la comunidadla variaciónlas precipitaciones a lo largoestos losla provinciaElaboraciónperfilesproyectoslas comunas miembro
# datos meteorológicosel ComitéProtección Civil Provincial con la
# finalidadjustificar solicitudconformaciónBrigadasCombate
# forestalla zona del Aconcagua, actualmente solo existenla costa.
#
# Esta información se utiliza como apoyola tomadecisionesel calculola distribuciónaguael cauce natural Rio ChoapaPara estimar la disponibilidad del recursoel río Mauleestudio la correlación entre temperatura media, extremas y precipitacionesel impactoasistencia a terapias kinesicasestoy preparando una actividad motivacional con niñas scout12 a 15 añosunos proyectos que deben generar y quiero reflexionar con ellas sobre
# cambio climático.Hola,Me pregunto si tendran los archivos espacialeslos datos que entregan aqui? Estaria mu interesadopoder obtenerlos.El uso es para:Investigacion y desarrolloun indicadoragua
# Muchas Gracias Felipe BenraAnalisisimpacto cambio climatico sobre recursos hidicosEstimados: Me encuentro investigando la situación hídricael surChile, y quería solicitar simulaciones que contemplen datoslas regionesBío Bío, Araucanía, Los Ríos y Los Lagos. Le saluda y agradece, Paz Neira. Antropóloga SocialAnálisistendenciasíndices climáticosla regiónAnálisistendenciasíndices climáticosModelación hidrológicaCR2
# Usodatosla redacciónun artículo Buenas tardes,
#
# Queremos obtener datossimulaciones climáticasChile y sudamérica,ponerloscontexto y realizar difusiónlos mismosnuestro sitio web (www.ambientaldata.com). La idea es potenciar la educación ambientalbase a datos científicos.
#
# Saludos y gracias, Obtención datoscaudal medio del río Aconcagua y sus canales,cálculocaudal disponible entrante al predio,trabajoinvestigación del curso técnicasriego. Proyecto estufiantil colectoraguas lluviasAnálisistendenciatemperaturas.Buenas noches, mi hijo10 años ingreso a la academia ecologicasu colegio (San Patricio, Antofagasta). Estamos buscando datos (temperatura y humedad)definir la cantidadagua que podriamos obtener por medio del rocioAntofagasta. La idea es recolectar esta aguael regadioplantas y huertos que
# los niños desarrollaran a lo largo del año. Sería bueno tener el registro diario y por hora del último año de
# ingeniería civil hidráulica.Trabajoinvestigación, delimitacióncuenca y caracterización del Río
# Tinguiririca.Balance hidrologicoDatos necesariostrabajoHidrologíaestudiouna cuencaparticularPara obtener la amenazaremocionmasala comunaCobquecuraTarea hidrologíael material se utilizarala evaluaciónun proyectotesis, con la finalidadevaluar las condiciones hidrologicasla serenaTRABAJO DE  HIDROLOGÍATareaHidrologíaAnálisisdatosuna Tarea Universitaria,el ramoHidrología correspondiente a la malla curricularla carreraIngeniería Civil.Se pretende hacer usobasesdatosprecipitaciones diariasalgunas estaciones pluviométricasla cuenca del Río Maipo desde la actualidad hasta hace unos 50 o 70 años atrás. Todo ello, con el objetivoanalizar el comportamiento que han tenido las precipitacionesel Sector del Cerro Divisadero, orientado a una investigaciónfactores condicionantes y gatillantesprocesosremociónmasael sector. Dicha investigación, se enmarca dentrouna tesispregradoalumnageología, quien solicita los datos.Para un trabajo universitario Análisisdatos con fines academicosproyecto estudianteproyecto estudianteTareahidrologíaModelación hidrologica del río PueloMe interesa la simulacion Precis-ECHAM del proyecto Anillos SOC28. La quiero utilizarmodelarSWAT el efecto del cambio climáticoChironta, con el finevaluar el efecto sobre la producción hidroeléctrica. Saludos.>>> Quisiera solicitar los datos del estudio "PRECIS Precis-CONAMA del>>> proyecto Anillos ACT-19:- Simulaci=C3=B3n Regional sobre un dominio que= incluye>>> todo Chile, 1960-1990 (baseline)".>>>>>> Los quiero utilizarmodelarSWAT el efecto del cambio clim=C3==A1tico>>>Chironta, con el finevaluar el efecto sobre la producci=C3=B3n>>> hidroel=C3=A9ctrica. Saludos.>>>>>> -->>> Este mensaje se ha enviado v=C3=ADa formulariocontacto desde CR2 | =Centro>>> del Clima y la Resiliencia (http://dgf.uchile.cl/~cr2webdev/cr2-base)>>>>>>> -->> Francisca Munoz Bravo, MSc <fmunoz@dgf.uchile.cl>>> Data and Computing Manager>> Center for Climate and Resilience Research (CR2) <www.cr2.cl>>> Blanco Encalada 2002, floor 4. Santiago, Chile>> FCFM, UniversidadChile.>> Office: +56 (0)2 2 9780668>> Mobile: +56 9 9 4401338>>>>>> --> Francisca Munoz Bravo, MSc <fmunoz@dgf.uchile.cl> <fmunoz@dgf.uchile.cl>> Data and Computing Manager> Center for Climate and Resilience Research (CR2) <www.cr2.cl>> Blanco Encalada 2002, floor 4. Santiago, Chile> FCFM, UniversidadChile.> Office: +56 (0)2 2 9780668> Mobile: +56 9 9 4401338>><div dir=3D"ltr">Solo los datos mensuales.</div><div class=3D"gmail_extra">=<br><div class=3D"gmail_quote">El 31agosto2016, 16:17, Francisca Mu=noz<span dir=3D"ltr">&lt;<a href=3D"mailto:fmunoz@dgf.uchile.cl" target=3D"=_blank">fmunoz@dgf.uchile.cl</a>&gt;</span> escribi=C3=B3:<br><blockquote c=lass=3D"gmail_quote" style=3D"margin:0 0 0 .8ex;border-left:1px #ccc solid;=padding-left:1ex"> =20   =20 =20  <div bgcolor=3D"#FFFFFF" text=3D"#000000">    <p>Hola Javier, desde aca te saldria mas rapido bajarlos, <br>    </p>    <p>Estanun servidor separado, y nosotros tambien nos conectamos      remotamente, lo que pasa es que estan medio desordenados todavia,<br>    </p>    <p>Necesitas los datos mensuales o diarios?</p>    <p>Fca<br>    </p>    <br>    <div>On 08/31/2016 01:08 PM, Javier Labrin      wrote:<br>    </div>    <blockquote type=3D"cite">      <div dir=3D"ltr">Estimada Francisca, si voy al departamento DGF =C2==BFme        podran compartir el registro completo del estudio=C2=A0<span style==3D"font-size:12.8px">Precis-CONAMA</span>?. Saludos.</div>      <div class=3D"gmail_extra"><br>        <div class=3D"gmail_quote">El 31agosto2016, 10:57,          Francisca Munoz<span dir=3D"ltr">&lt;<a href=3D"mailto:fmunoz@dgf=.uchile.cl" target=3D"_blank">fmunoz@dgf.uchile.cl</a>&gt;</span>          escribi=C3=B3:<br>          <blockquote class=3D"gmail_quote" style=3D"margin:0 0 0 .8ex;bord=er-left:1px #ccc solid;padding-left:1ex">Estimad@<br>            <br>            Estoy ordenando y ya traspasare las simulaciones que            mencionas, las que tenemos por el momento son las             ...
# (investigación)Análisisdatosprecipitación y temperatura mediael periodo 2001-2019, con el finobtener información del periodola MegasequíaChile central.Estudiotendencias climaticasChileel marcouna tesisdoctoradoRevisar la precipitación caída durante el periodo 2013-2014,las estaciones más cercanas al salar Gorbea, RegiónAtacama, (Lat -25,3, Long -68,7).tesispregradoSe solicita los datosprecipitación con finalidadun ProyectoTesis, relacionada a la comunaNogales.Basela elaboracióninvestigaciónun cursoMagisternecesito saber los datosprecipitacion que dejo el paso del fenómenos el niño este 2015chile, con la intenciónrealizar un ensayo sobre el niño 2015chileAnálisisseriestiempoprácticaDGAPráctica profesional DGAestudiosclimatología anliticaPara realizar un analisisprecipitaciones extremas.Muchas gracias.CD.Tareaintroduccion a la meteorologia.informaciónla caracterizaciónsitiotesisgradoinformaciónla  caracterizaciónsitiotesisgradoCorrelación con otras variablesel estudiotesisBusco los datosprecipitacioneshacer un análisisdicha variablemapas climaticos, como ejercicioel ramoClimala universidad.Para realizar informe sobre las precipitacioneslas regioneslos Rios y Lagos.Para tesispregrado sobre riesgos geológicosla ciudadVicuña, RegiónCoquimboBasicamente, me gustaria analizar las variaciones la precipatacion a lo largolos años.Soy un aficionado a la meteorologia, por tanto me llaman la atencion estos temas.Espero poder contar con los datos.Saludos,AnálisisprecipitaciónHualaihuéBuen día, como bibliotecala universidad, estamos ayudando a alumnosmedicinaesta casaestudiosun trabajoinvestigación, sobre el promediolas temperaturasChillan, Octava región entre los años 2006 y 2016.Me pueden ayudar a sintetizar la búsqueda???EstudioinundacionesestudioDesarrolloproyecto universitarioEntrenar una red neuronal MLPdeterminar la Temperaturaun determinado día según el registrotemperaturas previoel país.Would like to look at precip records for signs of droughts.Analisisseriestiempo y cruces con otras variablesestudio y caracterizacionfactores climaticoscombarbalaEstudios meteorológicos ycambio climático.ConstrucciónClimadiagramas Me encuentro haciendo una investigación sobre inundaciones y me seríamucha ayuda los datosprecipitaciones que ustedes poseen,la provinciaCautínNecesidadconocer proyecciones climáticaslos
omico ni intelectuales solamente academico, graciasVisualizacióndatos.MemoriaTesisMemoriatitulo MagisterCiencias UMag.gracias.Memoriatitulo MagisterCiencias UMAG.Muchas gracias.Análisisdatosestudio.MemoriatítuloMemoriatítulomemoriatesismagisterTesispost grado, conocer los datosprecipitaciones del ultimo periodo.Trabajo Universidadpara proyectotesispara la utilizaciónestosmi tesisPara mi tesisEstudios académicosdiploma uchileTesisMagísterTrabajola universidadTrabajo memoriatitulo, estaciones Lequena y SiloliPara la realizaciónproyectotitulodatos relevanteselaboracióntesisTESIS DE PREGRADOTesisEstudio Estimados: Los datosmi caso serán utilizados con fines académicos, ya que me encuentro realizando mi trabajotesis.Tesis
# Trabajola universidadNos están solicitando hacer usola estadística con diferentes basesdatos y me interesa hacer estadística con este tipoinformación (precipitación y temperatura) solo que la página oficialMéxico (CONAGUA) no tiene bases disponibles por el momento.
#
# Saludos.
# memoriapregradoMemoriaPregradoAcademicoLos datos solicitados son con fines académicos y estudiantiles.  trabajoinvestigacionTesis MagisterinformaicontesisinformaciontesisMaterialestudioSolo conocer las proyecciones esperadasEstudioMemoriaTítuloPregradoUsotesisJunto con saludar me gustaría tener acceso a información mencionada, como apoyomi tesismagíster. Muchas gracias.DiscusióntesisAnálisisdatos y estudiosProyectotítuloperfil cambio climaticoEstudiotesis.
# antecedentesTesisParticipaciónproyecto afínRealizaciónproyectotituloAplicación a escenariosimulaciones.información va a ser utilizada ara un proyectola universidad finis
# terraeMe gustaría poder usarlosmi tesispregradotesisTesissolamentefines academicas y conocimiento propioTrabajo universidadTrabajos académicoscursosdoctoradoBaseDatosmi memoriatituloTrabajola universidadtesis magistertesismagistercambio climáticoAprender sobre el cambio climáticoGENERAR BASE DE OPINION SOBRE LOS EVENTOS NATURALES QUE OCURRENESTUDIO DE VARIABLES ECOLOGICASPreparaciónpresentaciones relacionadas al cambio climático y déficit hídrico
# Recopilacióninformacióngenerar un texto informativo.Mi hija viaja permanentemente dentroChile y necesita  informaciónComplementar datosdiversidad vegetal
# ...
#
# Espero su respuesta
#
# SaludosSe va a realizar una recopilacióndatos que den cuenta sobre el cambio climático existenteChile, generado por la emisióngases a la atmósfera. Hola , Necesito los datos históricosla temperatura del SectorTeno región del maule, puesto que se estudiara el rió Teno por temascambio climático
# El historial debeser mas15 años
# Saludos cordiales.Para tesispregradola carreraGeografía, UPLA. We would like to use these data for comparison to precipitation modeling we are doing using water isotopes in the Patagonian and South Central Andes.Proyecto Tesis Estimados Sres. CR2, Junto con saludar, quisiera ver la posibilidadsolicitar los datos del proyecto PRECIS Precis-CONAMA del proyecto Anillos ACT-19:- Simulación Regional sobre un dominio que incluye todo Chile, 1960-1990 (baseline) ; 2071-2100 (B2, A2). De antemano Muchas Gracias! Saluda Atte. Alexander MolinaEstudiosdownscaling estadísticoestudiodownscaling estadísticoel CR2Los datos serán utilizadosun proyectodoctorado, analizando como las tendenciastemperatura los últimos años están afectando los glaciaresla zona centralChile. Gracias por el trabajo realizadola compilacióndatosLos datos serán utilizadosun proyectodoctorado, analizando como las tendenciastemperatura los últimos años están afectando los gl